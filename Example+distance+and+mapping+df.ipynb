# %% [markdown]
# ##### Distance data frame for one paragraph in a data set #####

# %%
import pandas as pd
import csv
egdf=pd.read_csv("/home/anjana/egdf.csv", header=0, index_col=0)
egdf
# Out:
#     DataSetno  Parano  Qnno  Sentno  w2vDistance  NormW2vDistance  Rank_x  \
# 0           0       0     0       0     2.652292         0.912598     3.0
# 1           0       0     0       1     2.631091         0.905303     2.0
# 2           0       0     0       2     2.906310         1.000000     7.0
# 3           0       0     0       3     2.734407         0.940852     5.0
# 4           0       0     0       4     2.763077         0.950717     6.0
# 5           0       0     0       5     2.120559         0.729640     1.0
# 6           0       0     0       6     2.690732         0.925824     4.0
# 7           0       0     1       0     2.678404         1.000000     7.0
# 8           0       0     1       1     2.437435         0.910033     3.0
# 9           0       0     1       2     2.435459         0.909295     2.0
# 10          0       0     1       3     2.067550         0.771934     1.0
# 11          0       0     1       4     2.542102         0.949111     6.0
# ...

# %%
weights = [0.2,0.5,0.8]

# %% [markdown]
# ##### First rank sentence and  Mapping data frame #####

# %%
egmapping = pd.read_csv("/home/anjana/egmapping.csv", header=0, index_col=0)
egmapping
# Out:
#     DataSetno  Parano  Qnno  ActualSent  w2vpred_sent  TagPred_Sent  \
# 5           0       0     0           6             5             1
# 10          0       0     1           3             3             4
# 17          0       0     2           4             3             1
# 24          0       0     3           5             3             4
# 31          0       0     4           2             3             4
#
#     TagNerpred_Sent  I_Weipred_Sent  II_Weipred_Sent  III_Weipred_Sent  \
# 5                 4               1                5                 5
# 10                4               4                3                 3
# 17                4               1                3                 3
# 24                4               4                4                 3
# 31                4               4                3                 3
#
#     w2v_mapping  Tag_mapping  TagNer_mapping  I_Wei_mapping  II_Wei_mapping  \
# ...

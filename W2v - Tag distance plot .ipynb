# %% [markdown]
# ##### Distance data frame for one paragraph from First data set #####

# %%
import pandas as pd
import csv
egdf=pd.read_csv("/home/anjana/egfinaldf", header=0, index_col=0)
egdf.rename(columns={'Rank_x': 'W2vRank','Rank_y':'TagRank','Rank': 'TagNerRank'}, inplace=True)
egdf
# Out:
#     DataSetno  Parano  Qnno  Sentno  w2vDistance  NormW2vDistance  W2vRank  \
# 0           0       0     0       0     2.652292         0.912598      3.0
# 1           0       0     0       1     2.631091         0.905303      2.0
# 2           0       0     0       2     2.906310         1.000000      7.0
# 3           0       0     0       3     2.734407         0.940852      5.0
# 4           0       0     0       4     2.763077         0.950717      6.0
# 5           0       0     0       5     2.120559         0.729640      1.0
# 6           0       0     0       6     2.690732         0.925824      4.0
# 7           0       0     1       0     2.678404         1.000000      7.0
# 8           0       0     1       1     2.437435         0.910033      3.0
# 9           0       0     1       2     2.435459         0.909295      2.0
# 10          0       0     1       3     2.067550         0.771934      1.0
# ...

# %%
weights = [0.2,0.5,0.8]

# %% [markdown]
# ##### First rank sentence and  Mapping data frame #####

# %%
egmapping = pd.read_csv("/home/anjana/egmapping", header=0, index_col=0)
egmapping.rename(columns={'Sentno': 'W2vpred_Sent'}, inplace=True)
egmapping
# Out:
#     DataSetno  Parano  Qnno  W2vpred_Sent  ActualSent  TagPred_Sent  \
# 5           0       0     0             5           6             4
# 10          0       0     1             3           3             4
# 17          0       0     2             3           4             6
# 24          0       0     3             3           5             4
# 31          0       0     4             3           2             4
#
#     TagNerpred_Sent  I_Weipred_Sent  II_Weipred_Sent  III_Weipred_Sent  \
# 5                 4               4                5                 5
# 10                4               4                3                 3
# 17                4               3                3                 3
# 24                4               4                4                 5
# 31                4               4                3                 3
#
#     w2v_mapping  Tag_mapping  TagNer_mapping  I_Wei_mapping  II_Wei_mapping  \
# ...

# %% [markdown]
# ###### Data frame for w2v- Tag distance plot #####

# %% [markdown]
# * Column 'Class' will be '1'
#
#
# If either 'Normw2vDistance' or 'NormTagDistance' hit the 'Actual answer'.   i.e either w2v_mapping or Tag_mapping is 1.
#
#  or
#
#
# Both features hit the actual answer sentence. i.e both w2v_mapping and Tag_mappings are 1.
#
# * Column 'Class' will be '0' if none of the features doesn't hit the 'Actual answer'. i.e w2v_mapping and Tag_mappings are Zero.

# %% [markdown]
# ##### Example data frame -- For the First paragrapgh from First data set #####

# %%
Plotdf = pd.read_csv("/home/anjana/plotegdf", header=0, index_col=0)
Plotdf.rename(columns = {'union_mapping':'Class'},inplace=True)
Plotdf
# Out:
#     DataSetno  Parano  Qnno  Sentno  NormW2vDistance  NormTagDistance  \
# 0           0       0     0       0         0.912598         1.000000
# 1           0       0     0       1         0.905303         0.895863
# 2           0       0     0       2         1.000000         0.868555
# 3           0       0     0       3         0.940852         0.920727
# 4           0       0     0       4         0.950717         0.810323
# 5           0       0     0       5         0.729640         0.897402
# 6           0       0     0       6         0.925824         0.990372
# 7           0       0     1       0         1.000000         0.831396
# 8           0       0     1       1         0.910033         1.000000
# 9           0       0     1       2         0.909295         0.970154
# 10          0       0     1       3         0.771934         0.961347
# 11          0       0     1       4         0.949111         0.785196
# ...

# %% [markdown]
# ##### Plot for First data set #####

# %% [markdown]
# * Yellow - if class = 1
# * Blue - if class = 0

# %%
egplot_df = pd.read_csv("/home/anjana/plotegdf", header=0, index_col=0)

# %%
# %matplotlib nbagg
plt.scatter(egplot_df.NormW2vDistance, egplot_df.NormTagDistance, c = egplot_df.union_mapping)
plt.show() 
plt.xlabel('Normalized w2v distance', fontsize=10)
plt.ylabel('Normalized Tag distance', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ##### Plot for 50 data sets #####

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation
# %matplotlib nbagg

# %%
plot_df = pd.read_csv("/home/anjana/plotdf", header=0, index_col=0)

# %%
plt.scatter(plot_df.NormW2vDistance, plot_df.NormTagDistance, c = plot_df.union_mapping)
plt.show()
plt.xlabel('Normalized w2v distance', fontsize=10)
plt.ylabel('Normalized Tag distance', fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
